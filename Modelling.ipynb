# %% [markdown]
# # Modelling

# %%
# read in libraries
try:
    import re
    import pandas as pd
    import numpy as np

    from flaml import AutoML

    import sklearn.metrics as metrics

    from evidently.report import Report
    from evidently.metric_preset import ClassificationPreset

    from evidently.test_suite import TestSuite
    from evidently.test_preset import BinaryClassificationTestPreset
except:
    # !pip install -r requirements.txt

# %%
# read in csv files from data preprocessing notebook
X_train = pd.read_csv('X_train.csv')
y_train = pd.read_csv('y_train.csv')

X1_test = pd.read_csv('X1_test.csv')
y1_test = pd.read_csv('y1_test.csv')

X2_test = pd.read_csv('X2_test.csv')
y2_test = pd.read_csv('y2_test.csv')

X_noise = pd.read_csv('X_noise.csv')
y_noise = pd.read_csv('y_noise.csv')

# %%
# change from DataFrame to Series for AutoML
y_train = y_train.squeeze()

# %%
# using FLAML - AutoML

# initialize an AutoML instance
automl = AutoML()
# specify AutoML goal and constraint
automl_settings = {
    "time_budget": 25, # seconds
    "metric": 'f1',
    "task": 'classification',
    "log_file_name": "automl.log",
}
# train with labeled input data
automl.fit(X_train, y_train, **automl_settings)
# Out:
# [flaml.automl.automl: 04-19 20:59:13] {2726} INFO - task = classification
# [flaml.automl.automl: 04-19 20:59:13] {2728} INFO - Data split method: stratified
# [flaml.automl.automl: 04-19 20:59:13] {2731} INFO - Evaluation method: holdout
# [flaml.automl.automl: 04-19 20:59:13] {2858} INFO - Minimizing error metric: 1-f1
# [flaml.automl.automl: 04-19 20:59:13] {3004} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'lrl1']
# [flaml.automl.automl: 04-19 20:59:13] {3334} INFO - iteration 0, current learner lgbm
# [flaml.automl.automl: 04-19 20:59:14] {3472} INFO - Estimated sufficient time budget=182669s. Estimated necessary time budget=4211s.
# [flaml.automl.automl: 04-19 20:59:14] {3519} INFO -  at 4.9s,	estimator lgbm's best error=1.0000,	best estimator lgbm's best error=1.0000
# [flaml.automl.automl: 04-19 20:59:14] {3334} INFO - iteration 1, current learner lgbm
# [flaml.automl.automl: 04-19 20:59:15] {3519} INFO -  at 6.0s,	estimator lgbm's best error=1.0000,	best estimator lgbm's best error=1.0000
# [flaml.automl.automl: 04-19 20:59:15] {3334} INFO - iteration 2, current learner lgbm
# [flaml.automl.automl: 04-19 20:59:16] {3519} INFO -  at 6.3s,	estimator lgbm's best error=1.0000,	best estimator lgbm's best error=1.0000
# [flaml.automl.automl: 04-19 20:59:16] {3334} INFO - iteration 3, current learner lgbm
# [flaml.automl.automl: 04-19 20:59:16] {3519} INFO -  at 6.8s,	estimator lgbm's best error=0.0644,	best estimator lgbm's best error=0.0644
# [flaml.automl.automl: 04-19 20:59:16] {3334} INFO - iteration 4, current learner xgboost
# [flaml.automl.automl: 04-19 20:59:16] {3519} INFO -  at 7.0s,	estimator xgboost's best error=0.0673,	best estimator lgbm's best error=0.0644
# [flaml.automl.automl: 04-19 20:59:16] {3334} INFO - iteration 5, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:17] {3519} INFO -  at 7.1s,	estimator xgboost's best error=0.0664,	best estimator lgbm's best error=0.0644
# [flaml.automl.automl: 04-19 20:59:17] {3334} INFO - iteration 6, current learner lgbm
# [flaml.automl.automl: 04-19 20:59:17] {3519} INFO -  at 7.3s,	estimator lgbm's best error=0.0644,	best estimator lgbm's best error=0.0644
# [flaml.automl.automl: 04-19 20:59:17] {3334} INFO - iteration 7, current learner lgbm
# [flaml.automl.automl: 04-19 20:59:17] {3519} INFO -  at 7.8s,	estimator lgbm's best error=0.0644,	best estimator lgbm's best error=0.0644
# [flaml.automl.automl: 04-19 20:59:17] {3334} INFO - iteration 8, current learner lgbm
# [flaml.automl.automl: 04-19 20:59:18] {3519} INFO -  at 8.6s,	estimator lgbm's best error=0.0644,	best estimator lgbm's best error=0.0644
# [flaml.automl.automl: 04-19 20:59:18] {3334} INFO - iteration 9, current learner xgboost
# [flaml.automl.automl: 04-19 20:59:18] {3519} INFO -  at 8.8s,	estimator xgboost's best error=0.0664,	best estimator lgbm's best error=0.0644
# [flaml.automl.automl: 04-19 20:59:18] {3334} INFO - iteration 10, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:18] {3519} INFO -  at 8.9s,	estimator xgboost's best error=0.0664,	best estimator lgbm's best error=0.0644
# [flaml.automl.automl: 04-19 20:59:18] {3334} INFO - iteration 11, current learner xgboost
# [flaml.automl.automl: 04-19 20:59:18] {3519} INFO -  at 9.0s,	estimator xgboost's best error=0.0564,	best estimator xgboost's best error=0.0564
# [flaml.automl.automl: 04-19 20:59:18] {3334} INFO - iteration 12, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:19] {3519} INFO -  at 9.1s,	estimator xgboost's best error=0.0552,	best estimator xgboost's best error=0.0552
# [flaml.automl.automl: 04-19 20:59:19] {3334} INFO - iteration 13, current learner xgboost
# [flaml.automl.automl: 04-19 20:59:19] {3519} INFO -  at 9.3s,	estimator xgboost's best error=0.0519,	best estimator xgboost's best error=0.0519
# [flaml.automl.automl: 04-19 20:59:19] {3334} INFO - iteration 14, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:19] {3519} INFO -  at 9.5s,	estimator xgboost's best error=0.0519,	best estimator xgboost's best error=0.0519
# [flaml.automl.automl: 04-19 20:59:19] {3334} INFO - iteration 15, current learner xgboost
# [flaml.automl.automl: 04-19 20:59:19] {3519} INFO -  at 9.6s,	estimator xgboost's best error=0.0467,	best estimator xgboost's best error=0.0467
# [flaml.automl.automl: 04-19 20:59:19] {3334} INFO - iteration 16, current learner lgbm
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:20] {3519} INFO -  at 10.2s,	estimator lgbm's best error=0.0644,	best estimator xgboost's best error=0.0467
# [flaml.automl.automl: 04-19 20:59:20] {3334} INFO - iteration 17, current learner xgboost
# [flaml.automl.automl: 04-19 20:59:20] {3519} INFO -  at 10.4s,	estimator xgboost's best error=0.0386,	best estimator xgboost's best error=0.0386
# [flaml.automl.automl: 04-19 20:59:20] {3334} INFO - iteration 18, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:20] {3519} INFO -  at 10.5s,	estimator xgboost's best error=0.0386,	best estimator xgboost's best error=0.0386
# [flaml.automl.automl: 04-19 20:59:20] {3334} INFO - iteration 19, current learner xgboost
# [flaml.automl.automl: 04-19 20:59:20] {3519} INFO -  at 10.7s,	estimator xgboost's best error=0.0386,	best estimator xgboost's best error=0.0386
# [flaml.automl.automl: 04-19 20:59:20] {3334} INFO - iteration 20, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:20] {3519} INFO -  at 11.0s,	estimator xgboost's best error=0.0375,	best estimator xgboost's best error=0.0375
# [flaml.automl.automl: 04-19 20:59:20] {3334} INFO - iteration 21, current learner lgbm
# [flaml.automl.automl: 04-19 20:59:21] {3519} INFO -  at 11.8s,	estimator lgbm's best error=0.0515,	best estimator xgboost's best error=0.0375
# [flaml.automl.automl: 04-19 20:59:21] {3334} INFO - iteration 22, current learner xgboost
# [flaml.automl.automl: 04-19 20:59:21] {3519} INFO -  at 12.0s,	estimator xgboost's best error=0.0374,	best estimator xgboost's best error=0.0374
# [flaml.automl.automl: 04-19 20:59:21] {3334} INFO - iteration 23, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:22] {3519} INFO -  at 12.2s,	estimator xgboost's best error=0.0374,	best estimator xgboost's best error=0.0374
# [flaml.automl.automl: 04-19 20:59:22] {3334} INFO - iteration 24, current learner xgboost
# [flaml.automl.automl: 04-19 20:59:22] {3519} INFO -  at 12.4s,	estimator xgboost's best error=0.0374,	best estimator xgboost's best error=0.0374
# [flaml.automl.automl: 04-19 20:59:22] {3334} INFO - iteration 25, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:22] {3519} INFO -  at 12.7s,	estimator xgboost's best error=0.0274,	best estimator xgboost's best error=0.0274
# [flaml.automl.automl: 04-19 20:59:22] {3334} INFO - iteration 26, current learner xgboost
# [flaml.automl.automl: 04-19 20:59:22] {3519} INFO -  at 12.9s,	estimator xgboost's best error=0.0274,	best estimator xgboost's best error=0.0274
# [flaml.automl.automl: 04-19 20:59:22] {3334} INFO - iteration 27, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:23] {3519} INFO -  at 13.1s,	estimator xgboost's best error=0.0248,	best estimator xgboost's best error=0.0248
# [flaml.automl.automl: 04-19 20:59:23] {3334} INFO - iteration 28, current learner xgboost
# [flaml.automl.automl: 04-19 20:59:23] {3519} INFO -  at 13.3s,	estimator xgboost's best error=0.0248,	best estimator xgboost's best error=0.0248
# [flaml.automl.automl: 04-19 20:59:23] {3334} INFO - iteration 29, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:23] {3519} INFO -  at 13.6s,	estimator xgboost's best error=0.0248,	best estimator xgboost's best error=0.0248
# [flaml.automl.automl: 04-19 20:59:23] {3334} INFO - iteration 30, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:23] {3519} INFO -  at 13.9s,	estimator xgboost's best error=0.0248,	best estimator xgboost's best error=0.0248
# [flaml.automl.automl: 04-19 20:59:23] {3334} INFO - iteration 31, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:24] {3519} INFO -  at 14.1s,	estimator xgboost's best error=0.0248,	best estimator xgboost's best error=0.0248
# [flaml.automl.automl: 04-19 20:59:24] {3334} INFO - iteration 32, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:24] {3519} INFO -  at 14.4s,	estimator xgboost's best error=0.0248,	best estimator xgboost's best error=0.0248
# [flaml.automl.automl: 04-19 20:59:24] {3334} INFO - iteration 33, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:25] {3519} INFO -  at 15.2s,	estimator xgboost's best error=0.0118,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:25] {3334} INFO - iteration 34, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:25] {3519} INFO -  at 15.3s,	estimator extra_tree's best error=0.1862,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:25] {3334} INFO - iteration 35, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:25] {3519} INFO -  at 15.3s,	estimator extra_tree's best error=0.1034,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:25] {3334} INFO - iteration 36, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:25] {3519} INFO -  at 15.3s,	estimator extra_tree's best error=0.1034,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:25] {3334} INFO - iteration 37, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:25] {3519} INFO -  at 15.4s,	estimator extra_tree's best error=0.1034,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:25] {3334} INFO - iteration 38, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:25] {3519} INFO -  at 15.5s,	estimator extra_tree's best error=0.0757,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:25] {3334} INFO - iteration 39, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:25] {3519} INFO -  at 15.6s,	estimator extra_tree's best error=0.0757,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:25] {3334} INFO - iteration 40, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:25] {3519} INFO -  at 15.6s,	estimator extra_tree's best error=0.0710,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:25] {3334} INFO - iteration 41, current learner rf
# [flaml.automl.automl: 04-19 20:59:25] {3519} INFO -  at 15.8s,	estimator rf's best error=0.0700,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:25] {3334} INFO - iteration 42, current learner rf
# [flaml.automl.automl: 04-19 20:59:25] {3519} INFO -  at 15.9s,	estimator rf's best error=0.0568,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:25] {3334} INFO - iteration 43, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:26] {3519} INFO -  at 16.4s,	estimator xgboost's best error=0.0118,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:26] {3334} INFO - iteration 44, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:26] {3519} INFO -  at 16.5s,	estimator extra_tree's best error=0.0574,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:26] {3334} INFO - iteration 45, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:26] {3519} INFO -  at 16.6s,	estimator extra_tree's best error=0.0574,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:26] {3334} INFO - iteration 46, current learner rf
# [flaml.automl.automl: 04-19 20:59:26] {3519} INFO -  at 16.7s,	estimator rf's best error=0.0568,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:26] {3334} INFO - iteration 47, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:26] {3519} INFO -  at 16.8s,	estimator extra_tree's best error=0.0574,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:26] {3334} INFO - iteration 48, current learner rf
# [flaml.automl.automl: 04-19 20:59:26] {3519} INFO -  at 16.9s,	estimator rf's best error=0.0568,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:26] {3334} INFO - iteration 49, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:27] {3519} INFO -  at 17.5s,	estimator xgboost's best error=0.0118,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:27] {3334} INFO - iteration 50, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:27] {3519} INFO -  at 17.7s,	estimator extra_tree's best error=0.0185,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:27] {3334} INFO - iteration 51, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:27] {3519} INFO -  at 17.8s,	estimator extra_tree's best error=0.0185,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:27] {3334} INFO - iteration 52, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:27] {3519} INFO -  at 18.0s,	estimator extra_tree's best error=0.0124,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:27] {3334} INFO - iteration 53, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:28] {3519} INFO -  at 18.5s,	estimator xgboost's best error=0.0118,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:28] {3334} INFO - iteration 54, current learner rf
# [flaml.automl.automl: 04-19 20:59:28] {3519} INFO -  at 18.6s,	estimator rf's best error=0.0519,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:28] {3334} INFO - iteration 55, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:28] {3519} INFO -  at 18.8s,	estimator extra_tree's best error=0.0124,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:28] {3334} INFO - iteration 56, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:28] {3519} INFO -  at 19.0s,	estimator extra_tree's best error=0.0124,	best estimator xgboost's best error=0.0118
# [flaml.automl.automl: 04-19 20:59:28] {3334} INFO - iteration 57, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:29] {3519} INFO -  at 19.1s,	estimator extra_tree's best error=0.0097,	best estimator extra_tree's best error=0.0097
# [flaml.automl.automl: 04-19 20:59:29] {3334} INFO - iteration 58, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:29] {3519} INFO -  at 19.4s,	estimator extra_tree's best error=0.0097,	best estimator extra_tree's best error=0.0097
# [flaml.automl.automl: 04-19 20:59:29] {3334} INFO - iteration 59, current learner rf
# [flaml.automl.automl: 04-19 20:59:29] {3519} INFO -  at 19.5s,	estimator rf's best error=0.0519,	best estimator extra_tree's best error=0.0097
# [flaml.automl.automl: 04-19 20:59:29] {3334} INFO - iteration 60, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:29] {3519} INFO -  at 19.7s,	estimator extra_tree's best error=0.0097,	best estimator extra_tree's best error=0.0097
# [flaml.automl.automl: 04-19 20:59:29] {3334} INFO - iteration 61, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:29] {3519} INFO -  at 20.0s,	estimator xgboost's best error=0.0118,	best estimator extra_tree's best error=0.0097
# [flaml.automl.automl: 04-19 20:59:29] {3334} INFO - iteration 62, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:30] {3519} INFO -  at 20.2s,	estimator extra_tree's best error=0.0097,	best estimator extra_tree's best error=0.0097
# [flaml.automl.automl: 04-19 20:59:30] {3334} INFO - iteration 63, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:30] {3519} INFO -  at 20.3s,	estimator extra_tree's best error=0.0097,	best estimator extra_tree's best error=0.0097
# [flaml.automl.automl: 04-19 20:59:30] {3334} INFO - iteration 64, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:30] {3519} INFO -  at 20.7s,	estimator xgboost's best error=0.0118,	best estimator extra_tree's best error=0.0097
# [flaml.automl.automl: 04-19 20:59:30] {3334} INFO - iteration 65, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:30] {3519} INFO -  at 20.9s,	estimator extra_tree's best error=0.0097,	best estimator extra_tree's best error=0.0097
# [flaml.automl.automl: 04-19 20:59:30] {3334} INFO - iteration 66, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:31] {3519} INFO -  at 21.4s,	estimator extra_tree's best error=0.0046,	best estimator extra_tree's best error=0.0046
# [flaml.automl.automl: 04-19 20:59:31] {3334} INFO - iteration 67, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:31] {3519} INFO -  at 21.7s,	estimator extra_tree's best error=0.0046,	best estimator extra_tree's best error=0.0046
# [flaml.automl.automl: 04-19 20:59:31] {3334} INFO - iteration 68, current learner rf
# [flaml.automl.automl: 04-19 20:59:31] {3519} INFO -  at 22.0s,	estimator rf's best error=0.0435,	best estimator extra_tree's best error=0.0046
# [flaml.automl.automl: 04-19 20:59:31] {3334} INFO - iteration 69, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:32] {3519} INFO -  at 22.2s,	estimator extra_tree's best error=0.0046,	best estimator extra_tree's best error=0.0046
# [flaml.automl.automl: 04-19 20:59:32] {3334} INFO - iteration 70, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:32] {3519} INFO -  at 22.5s,	estimator extra_tree's best error=0.0046,	best estimator extra_tree's best error=0.0046
# [flaml.automl.automl: 04-19 20:59:32] {3334} INFO - iteration 71, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:32] {3519} INFO -  at 22.8s,	estimator extra_tree's best error=0.0046,	best estimator extra_tree's best error=0.0046
# [flaml.automl.automl: 04-19 20:59:32] {3334} INFO - iteration 72, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:32] {3519} INFO -  at 23.0s,	estimator extra_tree's best error=0.0046,	best estimator extra_tree's best error=0.0046
# [flaml.automl.automl: 04-19 20:59:32] {3334} INFO - iteration 73, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:33] {3519} INFO -  at 23.3s,	estimator extra_tree's best error=0.0046,	best estimator extra_tree's best error=0.0046
# [flaml.automl.automl: 04-19 20:59:33] {3334} INFO - iteration 74, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:33] {3519} INFO -  at 23.5s,	estimator extra_tree's best error=0.0046,	best estimator extra_tree's best error=0.0046
# [flaml.automl.automl: 04-19 20:59:33] {3334} INFO - iteration 75, current learner rf
# [flaml.automl.automl: 04-19 20:59:33] {3519} INFO -  at 23.6s,	estimator rf's best error=0.0435,	best estimator extra_tree's best error=0.0046
# [flaml.automl.automl: 04-19 20:59:33] {3334} INFO - iteration 76, current learner rf
# [flaml.automl.automl: 04-19 20:59:33] {3519} INFO -  at 23.7s,	estimator rf's best error=0.0435,	best estimator extra_tree's best error=0.0046
# [flaml.automl.automl: 04-19 20:59:33] {3334} INFO - iteration 77, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:33] {3519} INFO -  at 23.9s,	estimator extra_tree's best error=0.0046,	best estimator extra_tree's best error=0.0046
# [flaml.automl.automl: 04-19 20:59:33] {3334} INFO - iteration 78, current learner xgboost
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:34] {3519} INFO -  at 24.3s,	estimator xgboost's best error=0.0118,	best estimator extra_tree's best error=0.0046
# [flaml.automl.automl: 04-19 20:59:34] {3334} INFO - iteration 79, current learner rf
# [flaml.automl.automl: 04-19 20:59:34] {3519} INFO -  at 24.3s,	estimator rf's best error=0.0435,	best estimator extra_tree's best error=0.0046
# [flaml.automl.automl: 04-19 20:59:34] {3334} INFO - iteration 80, current learner extra_tree
# [flaml.automl.automl: 04-19 20:59:34] {3519} INFO -  at 24.6s,	estimator extra_tree's best error=0.0046,	best estimator extra_tree's best error=0.0046
# [flaml.automl.automl: 04-19 20:59:34] {3334} INFO - iteration 81, current learner rf
# [flaml.automl.automl: 04-19 20:59:34] {3519} INFO -  at 24.7s,	estimator rf's best error=0.0435,	best estimator extra_tree's best error=0.0046
# [flaml.automl.automl: 04-19 20:59:34] {3334} INFO - iteration 82, current learner rf
# [flaml.automl.automl: 04-19 20:59:34] {3519} INFO -  at 24.8s,	estimator rf's best error=0.0435,	best estimator extra_tree's best error=0.0046
# [flaml.automl.automl: 04-19 20:59:34] {3334} INFO - iteration 83, current learner xgb_limitdepth
# [flaml.automl.automl: 04-19 20:59:34] {3519} INFO -  at 24.9s,	estimator xgb_limitdepth's best error=0.0458,	best estimator extra_tree's best error=0.0046
# [flaml.automl.automl: 04-19 20:59:34] {3334} INFO - iteration 84, current learner xgb_limitdepth
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /root/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [flaml.automl.automl: 04-19 20:59:34] {3519} INFO -  at 25.0s,	estimator xgb_limitdepth's best error=0.0458,	best estimator extra_tree's best error=0.0046
# [flaml.automl.automl: 04-19 20:59:34] {3334} INFO - iteration 85, current learner lrl1
# [flaml.automl.automl: 04-19 20:59:35] {3519} INFO -  at 25.7s,	estimator lrl1's best error=0.1757,	best estimator extra_tree's best error=0.0046
# /shared-libs/python3.9/py/lib/python3.9/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [flaml.automl.automl: 04-19 20:59:39] {3783} INFO - retrain extra_tree for 3.9s
# [flaml.automl.automl: 04-19 20:59:39] {3790} INFO - retrained model: ExtraTreesClassifier(criterion='entropy', max_features=0.29617042039215596,
#                      max_leaf_nodes=1659, n_estimators=8, n_jobs=-1,
#                      random_state=12032022)
# [flaml.automl.automl: 04-19 20:59:39] {3034} INFO - fit succeeded
# [flaml.automl.automl: 04-19 20:59:39] {3035} INFO - Time taken to find the best model: 21.434540033340454

# %%
# print the best model
print(automl.model.estimator)
# Out:
# ExtraTreesClassifier(criterion='entropy', max_features=0.29617042039215596,
#                      max_leaf_nodes=1659, n_estimators=8, n_jobs=-1,
#                      random_state=12032022)

# %%
# predict Test Batch 1
pred1 = automl.predict(X1_test)
print(pred1)
# Out:
# [0 0 0 ... 0 0 0]

# %%
# predict Test Batch 2
pred2 = automl.predict(X2_test)
print(pred2)
# Out:
# [0 0 0 ... 0 0 0]

# %%
# predict Noise Batch
pred_noise = automl.predict(X_noise)
print(pred_noise)
# Out:
# [0 0 0 ... 0 0 0]

# %%
# define functions that will output the result and reducue memory usage

def print_evaluate(true, predicted):  
    f1 = metrics.f1_score(true, predicted, average='macro')
    acc = metrics.accuracy_score(true, predicted)
    prec = metrics.precision_score(true, predicted, average='macro')
    recall = metrics.recall_score(true, predicted, average='macro')
    print('F1:', f1)
    print('Accuracy:', acc)
    print('Precision:', prec)
    print('Recall', recall)
    print('__________________________________')
    
def evaluate(true, predicted):
    f1 = metrics.f1_score(true, predicted, average='macro')
    acc = metrics.accuracy_score(true, predicted)
    prec = metrics.precision_score(true, predicted, average='macro')
    recall = metrics.recall_score(true, predicted, average='macro')
    return f1, acc, prec, recall

def reduce_mem_usage(df):
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        name =df[col].dtype.name 
        
        if col_type != object and col_type.name != 'category':
        #if name != "category":    
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
# checking the amount of similarities and differences for test batch 1

y1_test_array = y1_test.to_numpy()
y1_test_array = np.concatenate(y1_test_array, axis=0)
print("Number of differences: ", np.sum(y1_test_array != pred1))
print("Number of similarities: ", np.sum(y1_test_array == pred1))
# Out:
# Number of differences:  39
# Number of similarities:  53705

# %%
# checking the amount of similarities and differences for test batch 2

y2_test_array = y2_test.to_numpy()
y2_test_array = np.concatenate(y2_test_array, axis=0)
print("Number of differences: ", np.sum(y2_test_array != pred2))
print("Number of similarities: ", np.sum(y2_test_array == pred2))
# Out:
# Number of differences:  49
# Number of similarities:  77072

# %%
# checking the amount of similarities and differences for test batch 3 (noisy test batch)

y_noise_array = y_noise.to_numpy()
y_noise_array = np.concatenate(y_noise_array, axis=0)
print("Number of differences: ", np.sum(y_noise_array != pred_noise))
print("Number of similarities: ", np.sum(y_noise_array == pred_noise))
# Out:
# Number of differences:  6550
# Number of similarities:  58882

# %%
print('Test set 1 evaluation:\n_____________________________________')
print_evaluate(y1_test, pred1)

results_df = pd.DataFrame(data=[["Test Batch", *evaluate(y1_test, pred1), 0]], 
            columns=['Model', 'F1', 'Accuracy', 'Precision', 'Recall', 'Cross Validation'])
# Out:
# Test set 1 evaluation:
# _____________________________________
# F1: 0.84865557571781
# Accuracy: 0.9992743376004763
# Precision: 0.8259472266661266
# Recall 0.8747764697116459
# __________________________________

# %%
print('Test set 2 evaluation:\n_____________________________________')
print_evaluate(y2_test, pred2)

results_df = pd.DataFrame(data=[["Test Batch 2", *evaluate(y2_test, pred2), 0]], 
            columns=['Model', 'F1', 'Accuracy', 'Precision', 'Recall', 'Cross Validation'])
# Out:
# Test set 2 evaluation:
# _____________________________________
# F1: 0.879151294197551
# Accuracy: 0.9993646347946733
# Precision: 0.8700494820823774
# Recall 0.8887136142920204
# __________________________________

# %%
print('Noise set evaluation:\n_____________________________________')
print_evaluate(y_noise, pred_noise)

results_df = pd.DataFrame(data=[["Test Batch 2", *evaluate(y_noise, pred_noise), 0]], 
            columns=['Model', 'F1', 'Accuracy', 'Precision', 'Recall', 'Cross Validation'])
# Out:
# Noise set evaluation:
# _____________________________________
# F1: 0.48277222720663976
# Accuracy: 0.8998960753148306
# Precision: 0.7434666958684226
# Recall 0.5042784784531092
# __________________________________

# %%
# preparing data for Evidently

pred1 = pd.DataFrame(pred1)
pred2 = pd.DataFrame(pred2)
pred_noise = pd.DataFrame(pred_noise)

trueTest1 = pd.concat([X1_test, y1_test], axis=1)
predTest1 = pd.concat([X1_test, pred1], axis=1)
trueTest1.rename(columns={'Class': 'target'}, inplace=True)

trueTest2 = pd.concat([X2_test, y2_test], axis=1)
predTest2 = pd.concat([X2_test, pred2], axis=1)
trueTest2.rename(columns={'Class': 'target'}, inplace=True)

trueTest_noise = pd.concat([X_noise, y_noise], axis=1)
predTest_noise = pd.concat([X_noise, pred_noise], axis=1)
trueTest_noise.rename(columns={'Class': 'target'}, inplace=True)

# %%
train = X_train.assign(target = y_train)

# %%
test1 = trueTest1
test1['prediction'] = predTest1[0]

test2 = trueTest2
test2['prediction'] = predTest2[0]

test_noise = trueTest_noise
test_noise['prediction'] = predTest_noise[0]

# %%
# reduce memory usage in all test batches to optimize space

train = reduce_mem_usage(train)
test1 = reduce_mem_usage(test1)
test2 = reduce_mem_usage(test2)
test_noise = reduce_mem_usage(test_noise)
# Out:
# Memory usage of dataframe is 45.71 MB
# Memory usage after optimization is: 11.24 MB
# Decreased by 75.4%
# Memory usage of dataframe is 12.71 MB
# Memory usage after optimization is: 3.08 MB
# Decreased by 75.8%
# Memory usage of dataframe is 18.24 MB
# Memory usage after optimization is: 4.41 MB
# Decreased by 75.8%
# Memory usage of dataframe is 15.48 MB
# Memory usage after optimization is: 3.74 MB
# Decreased by 75.8%

# %%
classification_performance = Report(metrics=[
    ClassificationPreset()
])

# %% [markdown]
# ### Classification Performance: Test Batch 1 vs Test Batch 2

# %%
classification_performance.run(reference_data=test1, current_data=test2)
classification_performance.save_html("Test1_Test2_Report.html")

# %% [markdown]
# ### Classification Performance: Test Batch 2 vs Noisy Batch

# %%
classification_performance.run(reference_data=test2, current_data=test_noise)
classification_performance.save_html("Test2_Noise_Report.html")

# %% [markdown]
# ### Classification Test Suite: Test Batch 1 vs Test Batch 2

# %%
label_binary_classification_performance = TestSuite(tests=[
    BinaryClassificationTestPreset(),
])

# %%
label_binary_classification_performance.run(reference_data=test1, current_data=test2)
label_binary_classification_performance.save_html("Test1_Test2_TestSuite.html")

# %% [markdown]
# ### Classification Test Suite: Test Batch 2 vs Noisy Batch

# %%
label_binary_classification_performance.run(reference_data=test2, current_data=test_noise)
label_binary_classification_performance.save_html("Test2_Noise_TestSuite.html")

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=9dd4b1f4-9396-4609-8756-e5fddb45c25f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
